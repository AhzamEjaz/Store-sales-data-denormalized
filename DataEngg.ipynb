# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./super_store.csv")

# %%
print(df.size)
# Out:
# 176400

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df_copy = df.copy()
print(df_copy)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9795    SH-19975     Sally Hughsby  Corporate  United States          Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
#
#            State  Postal Code   Region       Product ID         Category  \
# 0       Kentucky      42420.0    South  FUR-BO-10001798        Furniture
# 1       Kentucky      42420.0    South  FUR-CH-10000454        Furniture
# 2     California      90036.0     West  OFF-LA-10000240  Office Supplies
# 3        Florida      33311.0    South  FUR-TA-10000577        Furniture
# 4        Florida      33311.0    South  OFF-ST-10000760  Office Supplies
# ...          ...          ...      ...              ...              ...
# 9795    Illinois      60610.0  Central  OFF-BI-10003429  Office Supplies
# 9796        Ohio      43615.0     East  OFF-AR-10001374  Office Supplies
# 9797        Ohio      43615.0     East  TEC-PH-10004977       Technology
# 9798        Ohio      43615.0     East  TEC-PH-10000912       Technology
# 9799        Ohio      43615.0     East  TEC-AC-10000487       Technology
#
#      Sub-Category                                       Product Name     Sales
# 0       Bookcases                  Bush Somerset Collection Bookcase  261.9600
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2          Labels  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4         Storage                     Eldon Fold 'N Roll Cart System   22.3680
# ...           ...                                                ...       ...
# 9795      Binders  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796          Art           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797       Phones                                        GE 30524EE4  235.1880
# 9798       Phones           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799  Accessories                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 18 columns]

# %%
print((df.dtypes).replace("object", "string"))
# Out:
# Row ID             int64
# Order ID          string
# Order Date        string
# Ship Date         string
# Ship Mode         string
# Customer ID       string
# Customer Name     string
# Segment           string
# Country           string
# City              string
# State             string
# Postal Code      float64
# Region            string
# Product ID        string
# Category          string
# Sub-Category      string
# Product Name      string
# Sales            float64
# dtype: object

# %% [markdown]
# ## Ship Mode Dimension table creation
# In this section, the following tasks have been performed:
# 1. Create a dimension table "dim_ship_mode" for ship mode column.
# 2. Map each ship mode unique value an ID.
# 3. Replace the name of the column "Ship Mode" in the main table to "sp_id".
# 4. Map each ID from "dim_ship_mode" to the main table "sp_id" and replace them.

# %%
#Assigning ship mode and ids
df["Ship Mode"].unique()
dim_ship_mode = pd.DataFrame({"sp_id" : (i[:2] for i in df["Ship Mode"].unique()), "ship_mode" : df["Ship Mode"].unique()})
#Assigning unique IDS
dim_ship_mode["sp_id"] = dim_ship_mode["sp_id"].str.upper()
print(dim_ship_mode)
# Out:
#   sp_id       ship_mode
# 0    SE    Second Class
# 1    ST  Standard Class
# 2    FI     First Class
# 3    SA        Same Day

# %%
df_copy.rename(columns = {"Ship Mode": "sp_id"}, inplace = True)
print(df_copy.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date           sp_id Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
#replace every entry with id
df_copy.replace(np.asarray(dim_ship_mode["ship_mode"]), dim_ship_mode["sp_id"], inplace = True)

# %%
#Exporting to csv file
dir_name = "./Dimension-tables/"
dim_ship_mode.to_csv((dir_name+ "dim_ship_mode.csv"), index = False)

# %% [markdown]
# ## Customer Information Dimension

# %%
dim_customer_info = pd.DataFrame({"customer_id": df_copy["Customer ID"], "customer_name": df_copy.pop("Customer Name")})

# %%
cust_id = dim_customer_info["customer_id"].unique()
cust_name = dim_customer_info["customer_name"].unique()
dim_customer_info = pd.DataFrame({"customer_id": cust_id, "customer_name": cust_name})

# %%
print(dim_customer_info)
df_copy.rename(columns = {"Customer ID": "customer_id"}, inplace = True)
# Out:
#     customer_id      customer_name
# 0      CG-12520        Claire Gute
# 1      DV-13045    Darrin Van Huff
# 2      SO-20335     Sean O'Donnell
# 3      BH-11710    Brosina Hoffman
# 4      AA-10480       Andrew Allen
# ..          ...                ...
# 788    CJ-11875       Carl Jackson
# 789    RS-19870         Roy Skaria
# 790    SC-20845         Sung Chung
# 791    RE-19405    Ricardo Emerson
# 792    SM-20905  Susan MacKendrick
#
# [793 rows x 2 columns]

# %%
df_copy
# Out:
#       Row ID        Order ID  Order Date   Ship Date sp_id customer_id  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    SE    DV-13045
# 3          4  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335
# 4          5  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335
# ...      ...             ...         ...         ...   ...         ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017    ST    SH-19975
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490
#
#         Segment        Country             City       State  Postal Code  \
# 0      Consumer  United States        Henderson    Kentucky      42420.0
# 1      Consumer  United States        Henderson    Kentucky      42420.0
# 2     Corporate  United States      Los Angeles  California      90036.0
# 3      Consumer  United States  Fort Lauderdale     Florida      33311.0
# 4      Consumer  United States  Fort Lauderdale     Florida      33311.0
# ...         ...            ...              ...         ...          ...
# 9795  Corporate  United States          Chicago    Illinois      60610.0
# 9796  Corporate  United States           Toledo        Ohio      43615.0
# 9797  Corporate  United States           Toledo        Ohio      43615.0
# 9798  Corporate  United States           Toledo        Ohio      43615.0
# 9799  Corporate  United States           Toledo        Ohio      43615.0
#
#        Region       Product ID         Category Sub-Category  \
# 0       South  FUR-BO-10001798        Furniture    Bookcases
# 1       South  FUR-CH-10000454        Furniture       Chairs
# 2        West  OFF-LA-10000240  Office Supplies       Labels
# 3       South  FUR-TA-10000577        Furniture       Tables
# 4       South  OFF-ST-10000760  Office Supplies      Storage
# ...       ...              ...              ...          ...
# 9795  Central  OFF-BI-10003429  Office Supplies      Binders
# 9796     East  OFF-AR-10001374  Office Supplies          Art
# 9797     East  TEC-PH-10004977       Technology       Phones
# 9798     East  TEC-PH-10000912       Technology       Phones
# 9799     East  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 17 columns]

# %%
dim_customer_info.to_csv((dir_name + "dim_customer_info.csv"), index = False)

# %% [markdown]
# ## Segment Dimensions table:

# %%
df_copy["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
dim_segment = pd.DataFrame(
    {
        "seg_id":["CON", "COR", "HOF"],
        "segment":["Consumer", "Corporate", "Home Office"]
    }
)

# %%
dim_segment.to_csv((dir_name + "dim_segment.csv"), index = False)

# %%
#Replacing in the main table
df_copy.rename({"Segment":"seg_id"},axis = 1, inplace = True)
df_copy.replace(np.asarray(dim_segment["segment"]), dim_segment["seg_id"], inplace = True)

# %% [markdown]
# ## Country

# %%
df_country = pd.read_csv("./country_code.csv")

# %%
df_country.drop(["Alpha-2 code", "Numeric"], axis = 1, inplace = True)
df_country.rename({"Alpha-3 code": "country_id"}, axis = 1, inplace = True)

# %%
df_country = df_country.loc[:,['country_id','Country']]
df_country.rename(columns = {
    'Country':"country_name"
}, inplace = True)

# %%
df_copy.replace(np.asarray(df_country["country_name"]), df_country["country_id"], inplace = True)
df_copy.rename({
    "Country":"country_id"
},axis = 1, inplace =True)

# %%
df_copy
# Out:
#       Row ID        Order ID  Order Date   Ship Date sp_id customer_id seg_id  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520    CON
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520    CON
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    SE    DV-13045    COR
# 3          4  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335    CON
# 4          5  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335    CON
# ...      ...             ...         ...         ...   ...         ...    ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017    ST    SH-19975    COR
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
#
#      country_id             City       State  Postal Code   Region  \
# 0            US        Henderson    Kentucky      42420.0    South
# 1            US        Henderson    Kentucky      42420.0    South
# 2            US      Los Angeles  California      90036.0     West
# 3            US  Fort Lauderdale     Florida      33311.0    South
# 4            US  Fort Lauderdale     Florida      33311.0    South
# ...         ...              ...         ...          ...      ...
# 9795         US          Chicago    Illinois      60610.0  Central
# 9796         US           Toledo        Ohio      43615.0     East
# 9797         US           Toledo        Ohio      43615.0     East
# 9798         US           Toledo        Ohio      43615.0     East
# 9799         US           Toledo        Ohio      43615.0     East
#
#            Product ID         Category Sub-Category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 9795  OFF-BI-10003429  Office Supplies      Binders
# 9796  OFF-AR-10001374  Office Supplies          Art
# 9797  TEC-PH-10004977       Technology       Phones
# 9798  TEC-PH-10000912       Technology       Phones
# 9799  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 17 columns]

# %%
df_country.to_csv((dir_name + "dim_country.csv"), index = False)

# %% [markdown]
# ## States

# %%
df_states = pd.read_csv("./president.csv")
df_states
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
#                     candidate              party_detailed writein  \
# 0               CARTER, JIMMY                    DEMOCRAT   False
# 1                FORD, GERALD                  REPUBLICAN   False
# 2              MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3     BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                   HALL, GUS         COMMUNIST PARTY USE   False
# ...                       ...                         ...     ...
# 4282            JORGENSEN, JO                 LIBERTARIAN   False
# 4283            PIERCE, BROCK                 INDEPENDENT   False
# 4284                      NaN                         NaN    True
# 4285                OVERVOTES                         NaN   False
# 4286               UNDERVOTES                         NaN   False
#
#       candidatevotes  totalvotes   version  notes party_simplified
# 0             659170     1182850  20210113    NaN         DEMOCRAT
# 1             504070     1182850  20210113    NaN       REPUBLICAN
# 2               9198     1182850  20210113    NaN            OTHER
# 3               6669     1182850  20210113    NaN            OTHER
# 4               1954     1182850  20210113    NaN            OTHER
# ...              ...         ...       ...    ...              ...
# 4282            5768      278503  20210113    NaN      LIBERTARIAN
# 4283            2208      278503  20210113    NaN            OTHER
# 4284            1739      278503  20210113    NaN            OTHER
# 4285             279      278503  20210113    NaN            OTHER
# 4286            1459      278503  20210113    NaN            OTHER
#
# [4287 rows x 15 columns]

# %%
state_id = df_states["state_po"].unique()
state_name_Caps = df_states["state"].unique()
state_name = []
for st_nm in state_name_Caps:
    state_name.append(st_nm.title())

df_states = pd.DataFrame({
    "state_id": state_id,
    "state_name": state_name
})

# %%
state_id
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
df_states.to_csv((dir_name + "dim_state.csv"), index = False)

# %%
df_copy.replace(state_name, state_id, inplace = True)

# %%
df_copy.rename(
{
    "State":"state_id"
}, axis = 1,
inplace = True
)

# %%
df_copy
# Out:
#       Row ID        Order ID  Order Date   Ship Date sp_id customer_id seg_id  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520    CON
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520    CON
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    SE    DV-13045    COR
# 3          4  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335    CON
# 4          5  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335    CON
# ...      ...             ...         ...         ...   ...         ...    ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017    ST    SH-19975    COR
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
#
#      country_id             City state_id  Postal Code   Region  \
# 0            US        Henderson       KY      42420.0    South
# 1            US        Henderson       KY      42420.0    South
# 2            US      Los Angeles       CA      90036.0     West
# 3            US  Fort Lauderdale       FL      33311.0    South
# 4            US  Fort Lauderdale       FL      33311.0    South
# ...         ...              ...      ...          ...      ...
# 9795         US          Chicago       IL      60610.0  Central
# 9796         US           Toledo       OH      43615.0     East
# 9797         US           Toledo       OH      43615.0     East
# 9798         US           Toledo       OH      43615.0     East
# 9799         US           Toledo       OH      43615.0     East
#
#            Product ID         Category Sub-Category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 9795  OFF-BI-10003429  Office Supplies      Binders
# 9796  OFF-AR-10001374  Office Supplies          Art
# 9797  TEC-PH-10004977       Technology       Phones
# 9798  TEC-PH-10000912       Technology       Phones
# 9799  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 17 columns]

# %%
df_copy.drop(["City", "Region", "Sub-Category"], axis = 1, inplace = True)

# %% [markdown]
# ## Category

# %%
category = df_copy["Category"].unique()
category_id = ["FUR", "OFS", "TEC"]

dim_category = pd.DataFrame({
    "category_id": category_id,
    "category": category
})
dim_category.to_csv((dir_name + "dim_category.csv"), index = False)
dim_category
# Out:
#   category_id         category
# 0         FUR        Furniture
# 1         OFS  Office Supplies
# 2         TEC       Technology

# %% [markdown]
# ## Product

# %%
df_copy.rename({
  "Product ID": "product_id",
    "Product Name":"product_name"
},axis = 1, inplace = True)
df_copy
# Out:
#       Row ID        Order ID  Order Date   Ship Date sp_id customer_id seg_id  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520    CON
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    SE    CG-12520    CON
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    SE    DV-13045    COR
# 3          4  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335    CON
# 4          5  US-2016-108966  11/10/2016  18/10/2016    ST    SO-20335    CON
# ...      ...             ...         ...         ...   ...         ...    ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017    ST    SH-19975    COR
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016    ST    CS-12490    COR
#
#      country_id state_id  Postal Code       product_id         Category  \
# 0            US       KY      42420.0  FUR-BO-10001798        Furniture
# 1            US       KY      42420.0  FUR-CH-10000454        Furniture
# 2            US       CA      90036.0  OFF-LA-10000240  Office Supplies
# 3            US       FL      33311.0  FUR-TA-10000577        Furniture
# 4            US       FL      33311.0  OFF-ST-10000760  Office Supplies
# ...         ...      ...          ...              ...              ...
# 9795         US       IL      60610.0  OFF-BI-10003429  Office Supplies
# 9796         US       OH      43615.0  OFF-AR-10001374  Office Supplies
# 9797         US       OH      43615.0  TEC-PH-10004977       Technology
# 9798         US       OH      43615.0  TEC-PH-10000912       Technology
# 9799         US       OH      43615.0  TEC-AC-10000487       Technology
#
#                                            product_name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 14 columns]

# %%
dim_product = pd.DataFrame({
    "product_id":[],
    "product_name":[],
    "category_id":[]
})
product_id = df_copy["product_id"].unique()

for prod_id in product_id:
    dim_product.loc[len(dim_product)] = [prod_id, 
                                         df_copy[df_copy["product_id"] == prod_id]["product_name"].unique()[0],
                                         df_copy[df_copy["product_id"] == prod_id]["Category"].unique()[0]]

# %%
dim_product
# Out:
#            product_id                                       product_name  \
# 0     FUR-BO-10001798                  Bush Somerset Collection Bookcase
# 1     FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2     OFF-LA-10000240  Self-Adhesive Address Labels for Typewriters b...
# 3     FUR-TA-10000577      Bretford CR4500 Series Slim Rectangular Table
# 4     OFF-ST-10000760                     Eldon Fold 'N Roll Cart System
# ...               ...                                                ...
# 1856  TEC-AC-10002380       Sony 8GB Class 10 Micro SDHC R40 Memory Card
# 1857  TEC-PH-10002817                    RCA ViSYS 25425RE1 Corded phone
# 1858  TEC-MA-10003589                       Cisco 8961 IP Phone Charcoal
# 1859  OFF-AP-10003099                        Eureka Hand Vacuum, Bagless
# 1860  TEC-PH-10002645                                              LG G2
#
#           category_id
# 0           Furniture
# 1           Furniture
# 2     Office Supplies
# 3           Furniture
# 4     Office Supplies
# ...               ...
# 1856       Technology
# 1857       Technology
# 1858       Technology
# 1859  Office Supplies
# 1860       Technology
#
# [1861 rows x 3 columns]

# %%
dim_product.replace(
    np.asarray(dim_category["category"]),dim_category["category_id"],inplace = True)

# %%
dim_product.to_csv((dir_name + "dim_product_detail.csv"), index = False)

# %%
df_copy.rename({
    "Row ID": "row_id",
    "Order ID":"order_id",
    "Order Date":"order_date",
    "Ship Date":"ship_date",
    "Postal Code": "postal code",
    "Sales": "sales"
}, axis = 1, inplace = True)

# %%
df_copy.to_csv((dir_name + "fact_sales.csv"), index = False)
